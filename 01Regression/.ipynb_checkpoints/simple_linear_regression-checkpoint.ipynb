# %% [markdown]
# # Simple Linear Regression
#
# ![image.png](attachment:image.png)
#
# There is **One Dependent Variable** - Outcome, which we're trying to predict
#
# and **One Independent Variable** - Predictor
#
# *Basically, a linear equation*
#
#
# ![image-2.png](attachment:image-2.png)
#
# So, we're trying to fit the line to our data set

# %% [markdown]
# # Ordinary Least Squares
#
# This is a way of identifying the best fit line, since there could be multiple candidates.
#
# So we choose the line where sum of squares of distances of all the points from the line is least
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv("Salary_Data.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_test, regressor.predict(X_test), color='blue')
plt.title("Salary vs experience")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.scatter(X_train, y_train, color='red')
# ----> 2 plt.plot(X_train, regressor.predict(X_test), color='blue')
#       3 plt.title("Salary vs experience")
#       4 plt.xlabel("Years of experience")
#
# File ~/opt/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/anaconda3/envs/py310/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
# ...
